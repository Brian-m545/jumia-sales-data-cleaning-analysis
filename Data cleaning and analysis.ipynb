# %%
#required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reads the dataset
df = pd.read_csv('data1.csv')

# %%
#data exploration
df
# Out:
#               Deal                                       Product name  \
# 0   Tech week deal  VILLAON V101 1.77" Kabambe, Wireless FM, Camer...
# 1   Tech week deal  RichRipple M10 LED Display Bluetooth Headsets ...
# 2   Tech week deal  RichRipple Sports Bluetooth  Into The Ear Neck...
# 3   Tech week deal  Infinix Smart 8 6.6" HD, 2GB RAM + 64GB , Andr...
# 4   Tech week deal  Oraimo OPB-1100D Toast 15 Flash 10000mAh Fast ...
# ..             ...                                                ...
# 76    Out of Stock  Realme C11 2021, 6.5", 32GB + 2GB, (Dual SIM),...
# 77    Out of Stock  Realme C15, 6.5", 4 GB + 128 GB (Dual SIM) - Blue
# 78    Out of Stock  Realme C21Y, 6.5", 3 GB RAM+ 32 GB (Dual SIM),...
# 79    Out of Stock                              Realme Buds Q - Black
# 80    Out of Stock               Realme Smart Waterproof Band - Green
#
#    Current prices  old prices Discount 3        Rating        ic href 2  \
# ...

# %%
#checks for first 5 rows
df.head()
# Out:
#              Deal                                       Product name  \
# 0  Tech week deal  VILLAON V101 1.77" Kabambe, Wireless FM, Camer...
# 1  Tech week deal  RichRipple M10 LED Display Bluetooth Headsets ...
# 2  Tech week deal  RichRipple Sports Bluetooth  Into The Ear Neck...
# 3  Tech week deal  Infinix Smart 8 6.6" HD, 2GB RAM + 64GB , Andr...
# 4  Tech week deal  Oraimo OPB-1100D Toast 15 Flash 10000mAh Fast ...
#
#   Current prices  old prices Discount 3        Rating        ic href 2  \
# 0        KSh 675     KSh 852        21%  3.9 out of 5  [object Object]
# 1        KSh 413     KSh 861        52%  3.6 out of 5  [object Object]
# 2        KSh 319     KSh 599        47%  3.8 out of 5  [object Object]
# 3      KSh 9,297  KSh 13,999        34%    4 out of 5  [object Object]
# 4      KSh 1,000   KSh 1,800        44%  4.3 out of 5  [object Object]
#
#            add _ni src
# 0  Add to cart     NaN
# 1  Add to cart     NaN
# 2  Add to cart     NaN
# 3  Add to cart     NaN
# ...

# %%
#checks for last 5 rows
df.tail()
# Out:
#             Deal                                       Product name  \
# 76  Out of Stock  Realme C11 2021, 6.5", 32GB + 2GB, (Dual SIM),...
# 77  Out of Stock  Realme C15, 6.5", 4 GB + 128 GB (Dual SIM) - Blue
# 78  Out of Stock  Realme C21Y, 6.5", 3 GB RAM+ 32 GB (Dual SIM),...
# 79  Out of Stock                              Realme Buds Q - Black
# 80  Out of Stock               Realme Smart Waterproof Band - Green
#
#    Current prices  old prices Discount 3        Rating        ic href 2  \
# 76     KSh 13,000         NaN        NaN  3.8 out of 5  [object Object]
# 77     KSh 11,999  KSh 14,999        20%           NaN  [object Object]
# 78     KSh 15,998         NaN        NaN           NaN  [object Object]
# 79     KSh 31,000         NaN        NaN           NaN  [object Object]
# 80      KSh 2,299         NaN        NaN           NaN  [object Object]
#
#          add _ni src
# 76  Sold out     NaN
# 77  Sold out     NaN
# 78  Sold out     NaN
# 79  Sold out     NaN
# ...

# %%
# checks how many rows and columns
df.shape
# Out:
# (81, 9)

# %%
#checks on missing values
df.isnull().sum()
# Out:
# Deal              36
# Product name       0
# Current prices     0
# old prices        27
# Discount 3        27
# Rating            35
# ic href 2         30
# add                0
# _ni src           56
# dtype: int64

# %%
#Data cleaning
df = df.drop(columns = ['Deal','Rating', 'ic href 2', 'add', '_ni src'])

# %%
df.head()
# Out:
#                                         Product name Current prices  \
# 0  VILLAON V101 1.77" Kabambe, Wireless FM, Camer...        KSh 675
# 1  RichRipple M10 LED Display Bluetooth Headsets ...        KSh 413
# 2  RichRipple Sports Bluetooth  Into The Ear Neck...        KSh 319
# 3  Infinix Smart 8 6.6" HD, 2GB RAM + 64GB , Andr...      KSh 9,297
# 4  Oraimo OPB-1100D Toast 15 Flash 10000mAh Fast ...      KSh 1,000
#
#    old prices Discount 3
# 0     KSh 852        21%
# 1     KSh 861        52%
# 2     KSh 599        47%
# 3  KSh 13,999        34%
# 4   KSh 1,800        44%

# %%
df.isnull().sum()
# Out:
# Product name       0
# Current prices     0
# old prices        27
# Discount 3        27
# dtype: int64

# %%
df['old prices']= df['old prices'].fillna(0)

# %%
df.isnull().sum()
# Out:
# Product name       0
# Current prices     0
# old prices         0
# Discount 3        27
# dtype: int64

# %%
df['Discount 3']= df['Discount 3'].fillna(0)

# %%
df.isnull().sum()
# Out:
# Product name      0
# Current prices    0
# old prices        0
# Discount 3        0
# dtype: int64

# %%
df.head()
# Out:
#                                         Product name Current prices  \
# 0  VILLAON V101 1.77" Kabambe, Wireless FM, Camer...        KSh 675
# 1  RichRipple M10 LED Display Bluetooth Headsets ...        KSh 413
# 2  RichRipple Sports Bluetooth  Into The Ear Neck...        KSh 319
# 3  Infinix Smart 8 6.6" HD, 2GB RAM + 64GB , Andr...      KSh 9,297
# 4  Oraimo OPB-1100D Toast 15 Flash 10000mAh Fast ...      KSh 1,000
#
#    old prices Discount 3
# 0     KSh 852        21%
# 1     KSh 861        52%
# 2     KSh 599        47%
# 3  KSh 13,999        34%
# 4   KSh 1,800        44%

# %%
df.describe()
# Out:
#                                              Product name Current prices  \
# count                                                  81             81
# unique                                                 78             74
# top     RichRipple Pro3 Bluetooth Headsets Wireless Po...        KSh 449
# freq                                                    4              3
#
#         old prices  Discount 3
# count           81          81
# unique          46          30
# top              0           0
# freq            27          27

# %%
# Displays the culumns,number of records per column, data types of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Product name    81 non-null     object
#  1   Current prices  81 non-null     object
#  2   old prices      81 non-null     object
#  3   Discount 3      81 non-null     object
# dtypes: object(4)
# memory usage: 2.7+ KB

# %%
df = df.drop([70]) # dropping a row

# %%
df.head(71)
# Out:
#                                          Product name Current prices  \
# 0   VILLAON V101 1.77" Kabambe, Wireless FM, Camer...        KSh 675
# 1   RichRipple M10 LED Display Bluetooth Headsets ...        KSh 413
# 2   RichRipple Sports Bluetooth  Into The Ear Neck...        KSh 319
# 3   Infinix Smart 8 6.6" HD, 2GB RAM + 64GB , Andr...      KSh 9,297
# 4   Oraimo OPB-1100D Toast 15 Flash 10000mAh Fast ...      KSh 1,000
# ..                                                ...            ...
# 66   TAAR MOMENTO IOS To TYPE C DATA CABLE (6 M WRTY)        KSh 349
# 67     Baseus  1M 240W Tungsten Type-C to Type-C Gold      KSh 1,400
# 68  Infinix GT 20 Pro, 6.78", 256GB + 12GB RAM (Du...     KSh 38,200
# 69  C Idea 8-Inch, Android 12, Dual Camera, SIM, 2...      KSh 5,869
# 71  C Idea 10.1 Inch Android Tablet PC 12 Dual Cam...     KSh 10,699
#
#     old prices Discount 3
# 0      KSh 852        21%
# 1      KSh 861        52%
# 2      KSh 599        47%
# 3   KSh 13,999        34%
# ...

# %%
# converted the datatype from a str to a float
df['Current prices'] = df['Current prices'].str.replace('KSh',',').str.replace(',','').astype(float)

# %%
df.head()
# Out:
#                                         Product name  Current prices  \
# 0  VILLAON V101 1.77" Kabambe, Wireless FM, Camer...           675.0
# 1  RichRipple M10 LED Display Bluetooth Headsets ...           413.0
# 2  RichRipple Sports Bluetooth  Into The Ear Neck...           319.0
# 3  Infinix Smart 8 6.6" HD, 2GB RAM + 64GB , Andr...          9297.0
# 4  Oraimo OPB-1100D Toast 15 Flash 10000mAh Fast ...          1000.0
#
#    old prices Discount 3
# 0     KSh 852        21%
# 1     KSh 861        52%
# 2     KSh 599        47%
# 3  KSh 13,999        34%
# 4   KSh 1,800        44%

# %%
# converted the datatype from a str to a float
df['old prices'] = df['old prices'].str.replace('KSh',',').str.replace(',','').astype(float)

# %%
df.head()
# Out:
#                                         Product name  Current prices  \
# 0  VILLAON V101 1.77" Kabambe, Wireless FM, Camer...           675.0
# 1  RichRipple M10 LED Display Bluetooth Headsets ...           413.0
# 2  RichRipple Sports Bluetooth  Into The Ear Neck...           319.0
# 3  Infinix Smart 8 6.6" HD, 2GB RAM + 64GB , Andr...          9297.0
# 4  Oraimo OPB-1100D Toast 15 Flash 10000mAh Fast ...          1000.0
#
#    old prices Discount 3
# 0       852.0        21%
# 1       861.0        52%
# 2       599.0        47%
# 3     13999.0        34%
# 4      1800.0        44%

# %%
df.describe()
# Out:
#        Current prices    old prices
# count       80.000000     54.000000
# mean      5846.375000   7930.518519
# std       7055.573192   8829.208849
# min        220.000000    399.000000
# 25%        688.500000    826.000000
# 50%       2399.000000   2833.500000
# 75%       9073.500000  13999.000000
# max      38200.000000  40000.000000

# %%
df.head()
# Out:
#                                         Product name  Current prices  \
# 0  VILLAON V101 1.77" Kabambe, Wireless FM, Camer...           675.0
# 1  RichRipple M10 LED Display Bluetooth Headsets ...           413.0
# 2  RichRipple Sports Bluetooth  Into The Ear Neck...           319.0
# 3  Infinix Smart 8 6.6" HD, 2GB RAM + 64GB , Andr...          9297.0
# 4  Oraimo OPB-1100D Toast 15 Flash 10000mAh Fast ...          1000.0
#
#    old prices Discount 3
# 0       852.0        21%
# 1       861.0        52%
# 2       599.0        47%
# 3     13999.0        34%
# 4      1800.0        44%

# %%
df.head()
# Out:
#                                         Product name  Current prices  \
# 0  VILLAON V101 1.77" Kabambe, Wireless FM, Camer...           675.0
# 1  RichRipple M10 LED Display Bluetooth Headsets ...           413.0
# 2  RichRipple Sports Bluetooth  Into The Ear Neck...           319.0
# 3  Infinix Smart 8 6.6" HD, 2GB RAM + 64GB , Andr...          9297.0
# 4  Oraimo OPB-1100D Toast 15 Flash 10000mAh Fast ...          1000.0
#
#    old prices Discount 3
# 0       852.0        21%
# 1       861.0        52%
# 2       599.0        47%
# 3     13999.0        34%
# 4      1800.0        44%

# %%
df['Discount 3'] = df['Discount 3'].str.replace('%','').astype(float)

# %%
df.head()
# Out:
#                                         Product name  Current prices  \
# 0  VILLAON V101 1.77" Kabambe, Wireless FM, Camer...           675.0
# 1  RichRipple M10 LED Display Bluetooth Headsets ...           413.0
# 2  RichRipple Sports Bluetooth  Into The Ear Neck...           319.0
# 3  Infinix Smart 8 6.6" HD, 2GB RAM + 64GB , Andr...          9297.0
# 4  Oraimo OPB-1100D Toast 15 Flash 10000mAh Fast ...          1000.0
#
#    old prices  Discount 3
# 0       852.0        21.0
# 1       861.0        52.0
# 2       599.0        47.0
# 3     13999.0        34.0
# 4      1800.0        44.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Product name    80 non-null     object
#  1   Current prices  80 non-null     float64
#  2   old prices      54 non-null     float64
#  3   Discount 3      54 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 3.1+ KB

# %%
# checking the top discount - using descending order
Top_discount = df.sort_values(by ='Discount 3',ascending=False).head()

# %%
Top_discount
# Out:
#                                          Product name  Current prices  \
# 12  Oraimo PowerHub C 6-In-1 Smart  High Security ...          1699.0
# 1   RichRipple M10 LED Display Bluetooth Headsets ...           413.0
# 73  Jbl Tune 110 In-Ear Headphones - Black(1 YR WRTY)          1600.0
# 63  Hama Car Charger With Micro-USB Cable (102078)...          1495.0
# 56  Hama Data Cable Usb-a To Usb-c 1m (178395), (5...          1295.0
#
#     old prices  Discount 3
# 12      3700.0        54.0
# 1        861.0        52.0
# 73      3200.0        50.0
# 63      2990.0        50.0
# 56      2590.0        50.0

# %%
Top_Current_Price = df.sort_values(by = 'Current prices', ascending=False).head()

# %%
Top_Current_Price
# Out:
#                                          Product name  Current prices  \
# 68  Infinix GT 20 Pro, 6.78", 256GB + 12GB RAM (Du...         38200.0
# 79                              Realme Buds Q - Black         31000.0
# 17  Infinix Xpad (X1101B) Tablet, 11" - 256GB + 4G...         21199.0
# 40  Realme C21Y, 6.5", 4GB RAM + 64GB (Dual SIM), ...         17000.0
# 11  Infinix Hot 40 Pro, 6.78", 256GB + 8GB, 5000 m...         16399.0
#
#     old prices  Discount 3
# 68     40000.0         5.0
# 79         NaN         NaN
# 17     25000.0        15.0
# 40         NaN         NaN
# 11     20387.0        20.0

# %%
df.describe()
# Out:
#        Current prices    old prices  Discount 3
# count       80.000000     54.000000   54.000000
# mean      5846.375000   7930.518519   34.537037
# std       7055.573192   8829.208849   14.332590
# min        220.000000    399.000000    5.000000
# 25%        688.500000    826.000000   20.000000
# 50%       2399.000000   2833.500000   41.000000
# 75%       9073.500000  13999.000000   47.750000
# max      38200.000000  40000.000000   54.000000

# %%
df.rename(columns ={'Discount 3':'Discount'}, inplace=True)

# %%
df.describe()
# Out:
#        Current prices    old prices   Discount
# count       80.000000     54.000000  54.000000
# mean      5846.375000   7930.518519  34.537037
# std       7055.573192   8829.208849  14.332590
# min        220.000000    399.000000   5.000000
# 25%        688.500000    826.000000  20.000000
# 50%       2399.000000   2833.500000  41.000000
# 75%       9073.500000  13999.000000  47.750000
# max      38200.000000  40000.000000  54.000000

# %%
sns.histplot(df['Current prices'],kde=True)
plt.show()

# %%
sns.histplot(df['old prices'],kde=True)
plt.show()

# %%
sns.histplot(df['Discount'],kde=True)
plt.show()

# %%
df.describe()
# Out:
#        Current prices    old prices   Discount
# count       80.000000     54.000000  54.000000
# mean      5846.375000   7930.518519  34.537037
# std       7055.573192   8829.208849  14.332590
# min        220.000000    399.000000   5.000000
# 25%        688.500000    826.000000  20.000000
# 50%       2399.000000   2833.500000  41.000000
# 75%       9073.500000  13999.000000  47.750000
# max      38200.000000  40000.000000  54.000000

# %%
#checking outliers for current prices
sns.boxplot(y='Current prices', data=df)
# Out:
# <Axes: ylabel='Current prices'>

# %%
#lower and upper quartile
Q1 = df['Current prices'].quantile(0.25)
Q3 = df['Current prices'].quantile(0.75)
IQR = Q3 - Q1

# %%
IQR = Q3 - Q1

# %%
# Interquartile range
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
#removing outliers
outliers = df[(df['Current prices'] < lower_bound) | (df['Current prices'] > upper_bound)]
print("Outliers using IQR method:\n", outliers)
# Out:
# Outliers using IQR method:
#                                           Product name  Current prices  \
# 68  Infinix GT 20 Pro, 6.78", 256GB + 12GB RAM (Du...         38200.0
# 79                              Realme Buds Q - Black         31000.0
#
#     old prices  Discount
# 68     40000.0       5.0
# 79         NaN       NaN

# %%
sns.boxplot(y='old prices', data=df)
# Out:
# <Axes: ylabel='old prices'>

# %%
Q1 = df['old prices'].quantile(0.25)
Q3 = df['old prices'].quantile(0.75)
IQR = Q3 - Q1

# %%
IQR = Q3 - Q1

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
outliers = df[(df['old prices'] < lower_bound) | (df['old prices'] > upper_bound)]
print("Outliers using IQR method:\n", outliers)
# Out:
# Outliers using IQR method:
#                                           Product name  Current prices  \
# 68  Infinix GT 20 Pro, 6.78", 256GB + 12GB RAM (Du...         38200.0
#
#     old prices  Discount
# 68     40000.0       5.0

# %%
sns.boxplot(y='Discount', data=df)
# Out:
# <Axes: ylabel='Discount'>
